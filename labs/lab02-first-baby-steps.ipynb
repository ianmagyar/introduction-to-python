# %% [markdown]
# # Cvičenie 2: Prvé kroky v Pythone

# %% [markdown]
# Na dnešnom cvičení sa oboznámime so základnými jazykovými konštruktmi jazyka Python a napíšeme prvé jednoduché programy. Cieľom cvičenia je naučiť sa pracovať so štandardným vstupom a výstupom, elementárnymi typmi, základnými operáciami, ako aj s vetveniami a iteráciami.
#
# Programovať môžete vo vybranom vývojovom prostredí alebo priamo v tomto Jupyter notebooku.

# %% [markdown]
# ## 1. Hello, world!
#
# Tradičný prvý program, ktorý začiatočníci v ktoromkoľvek programovacom jazyku napíšu je *Hello, world!*. Jeho história siaha až do 70-tych rokov, keď ho Brian W. Kernighan a Dennis M. Ritchie použili vo svojej učebnici jazyka C *The C Programming Language* (1978). Kernighan program použil už skôr, v roku 1974 v Bell Laboratories. Úplne prvé použitie na výučbové účely pochádza z roku 1972, z knihy Kernighana *A Tutorial Introduction to the Language B*.
#
# Ako už iste viete, v jazyku C sa na štandardný výstup používa funkcia `printf`, ktorá výstup aj formátuje. Python je v tomto smere viac univerzálny, keďže veľkú časť formátovania vyrieši za vás, vy môžete rovno zadať reťazec, resp. hodnoty, ktoré chcete dať vypísať. V Pythone na štandardný výpis slúži funkcia [`print`](https://docs.python.org/3/library/functions.html#print).
#
# **Úloha:** Implementujte jednoduchý program, ktorý na štandardný výstup vypíše reťazec *Hello, world!* Pridáte sa tak k dlhému radu programátorov a k ich snahe osvojiť si nové programovacie jazyky.

# %%
# implement Hello, world! here

# %% [markdown]
# ## 2. Hello, ...!
#
# V ďalšom kroku náš program personalizujeme, a naučíte váš počítač, aby vás (alebo kohokoľvek iného) pozdravil. Upravte váš kód tak, aby sa najprv opýtal na meno používateľa, a následne vypísal pozdrav *Hello, _*, kde sa namiesto *_* vypíše zadané meno.
#
# Pre štandardný výstup použijeme funkciu [`input`](https://docs.python.org/3/library/functions.html#input), ktorá má jeden nepovinný parameter, a to `prompt`, teda krátky text, ktorý vysvetlí používateľovi, aký vstup má zadať. Funkcia vráti zadaný reťazec. V našom programe túto hodnotu potrebujeme uložiť do pomocnej premennej.
#
# **Úloha:** Implementujte jednoduchý program, ktorý sa opýta na meno používateľa, a následne ho pozdraví reťazcom *Hello, _!* Pri výpise máte niekoľko možností formátovania výstupu, [môžete si ich prelistovať tu](https://docs.python.org/3/tutorial/inputoutput.html#fancier-output-formatting).

# %%
# ask the user for their name

# write Hello, ...!

# %% [markdown]
# ## 3. Výpočet druhej mocniny
#
# **Úloha:** Napíšte program, ktorý ako vstup od používateľa načíta číslo (celé alebo desatinné) a vypíše druhú mocninu tohto čísla. Vyskúšajte obe základné možnosti výpočtu druhej mocniny: násobenie (operátor `*`) a priame umocňovanie (operátor `**`).

# %%
# ask the user to enter a number

# print the square of the number

# %% [markdown]
# **Úloha:** Upravte vaše riešenie tak, aby výsledok zaokrúhľoval na tri desatinné miesta.

# %% [markdown]
# ## 4. Parita čísla
#
# V našich programoch veľmi často potrebujeme spracovať hodnoty rôznymi spôsobmi na základe ich vlastností. Aby sme boli pripravení na túto situáciu, teraz napíšeme program, ktorý zistí, či číslo zadané používateľom je párne alebo nepárne.
#
# **Úloha:** Implementujte program, ktorý načíta číslo zo vstupu od používateľa, a následne vypíše, či číslo je párne alebo nepárne. Navrhnite pritom rôzne možnosti riešenia tohto problému, aby ste videli, že v programovaní zriedkakedy existuje iba jedno možné riešenie (aj keď veľa programátorov vám povie, že existuje jediné správne riešenie, nezhodnú sa na tom, ktoré to presne je).

# %%
# ask the user to enter an integer

# print even if number is even, odd if number is odd

# %% [markdown]
# ## 5. Spoločné delitele
#
# Keby stačilo pracovať vždy len s jednou hodnotou v našich programoch, život programátora by bol bez stresu. Realita je však iná, a práve preto musíme akceptovať skutočnosť, že naše programy sú plné rôznych hodnôt a premenných. Zatiaľ vás ale budeme šetriť, a napíšeme program, ktorý zoberie dva číselné vstupy od používateľa. Následne program vypíše všetky spoločné delitele týchto dvoch čísel. Pred tým, než sa spustíme do programovania, pouvažujte na možných riešeniach tohto problému (realizáca v Pythone vás zatiaľ nemusí trápiť).
#
# **Úloha:** Implementujte program, ktorý načíta dve celé čísla zo štandardného vstupu a vypíše všetky ich spoločné deliteľe, teda celé čísla, ktoré delia obe čísla bezo zvyšku.

# %%
# ask the user to enter two integers

# print all common divisors of the two numbers

# %% [markdown]
# ## 6. Hľadanie prvočísel
#
# V predošlých úlohách sme hľadali párne, nepárne čísla a delitele čísel. Nájdenie prvočísel je ale trošku náročnejšia úloha, no sme si istí, že vy to zvládnete bez problémov. Nieže by ste to potrebovali, ale na opakovanie vám prezradíme, že prvočíslo je celé číslo väčšie ako jedna, ktoré má presne dva delitele: 1 a seba samého.
#
# **Úloha:** Implementujte program, ktorý načíta celé číslo zo štandardného vstupu a následne vypíše, či dané číslo je alebo nie je prvočíslo.

# %%
# ask the user to input an integer

# print if number is prime or not
